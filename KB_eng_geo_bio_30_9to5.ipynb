# %%
import pandas as pd
import pyomo.environ as pyo
from pyomo.opt import SolverFactory
from pathlib import Path
import numpy as np
import math
from collections import defaultdict
from itertools import combinations

# %%
programme_courses = pd.read_csv("Cleaned_Data/Cleaned Programme-Courses.csv")
rooms = pd.read_csv("Cleaned_Data/Cleaned Rooms and Room Types .csv")
EMR = pd.read_csv("Cleaned_Data/Cleaned Event Module Room.csv")
EMR["Event Size"] = pd.to_numeric(EMR["Event Size"], errors="coerce").fillna(0)
SPME = pd.read_csv("2024-5 Student Programme Module Event.csv")

# %%
rooms_toy = rooms[rooms["Campus"] == "Kings Buildings"]
rooms_toy = rooms_toy[["Id", "Capacity", "Building.1", "Specialist room type"]]
#rooms_toy.loc[len(rooms_toy)] = ["0787_00_XX", 1000, "Sheep Shed"]
print(rooms_toy)
print("rows:", len(rooms_toy))
# Out:
#                   Id  Capacity             Building.1 Specialist room type
# 439  0616_00_00.01-E      86.0                 Alrick     General Teaching
# 440  0616_01_01.03-E      80.0                 Alrick  Computer Laboratory
# 441  0616_02_02.02-E      72.0                 Alrick     General Teaching
# 442   0640_00_G.0070     313.0          Ashworth Labs     General Teaching
# 443   0640_00_G.0080     116.0          Ashworth Labs           Laboratory
# ..               ...       ...                    ...                  ...
# 677    0621_01_1.304       NaN                   Crew         Meeting Room
# 678     0648_00_G.02       NaN    Roger Land Building         Meeting Room
# 679     0648_00_G.13       NaN    Roger Land Building         Meeting Room
# 680     0648_01_1.55       NaN    Roger Land Building         Meeting Room
# 681     0670_01_1.07       NaN  Waddington Building 1         Meeting Room
#
# [121 rows x 4 columns]
# rows: 121

# %%
target_buildings = [
    "Alrick",
    "Eng Sanderson Building",
    "Fleeming Jenkin",
    "Hudson Beare Building",
    "William Rankine",
    "Ashworth Labs",
    "Crew",
    "Daniel Rutherford Building",
    "Geology/Geophysics (Grant Institute)",
    "Peter Wilson Building",
    "Roger Land Building",
    "Swann Building",
    "Waddington Building 1"
]

rooms_toy = rooms[
    (rooms["Campus"] == "Kings Buildings") &
    (rooms["Building.1"].isin(target_buildings))
].copy()

rooms_toy = rooms_toy[["Id", "Capacity", "Building.1", "Specialist room type"]]

print(rooms_toy)
print("rows:", len(rooms_toy))
# Out:
#                         Id  Capacity                            Building.1  \
# 439        0616_00_00.01-E      86.0                                Alrick
# 440        0616_01_01.03-E      80.0                                Alrick
# 441        0616_02_02.02-E      72.0                                Alrick
# 442         0640_00_G.0070     313.0                         Ashworth Labs
# 443         0640_00_G.0080     116.0                         Ashworth Labs
# 444         0640_01_1.0107      88.0                         Ashworth Labs
# 445         0640_01_1.0114      33.0                         Ashworth Labs
# 446         0640_01_1.0115      35.0                         Ashworth Labs
# 447         0640_01_1.0150      12.0                         Ashworth Labs
# 448           0640_01_1.03      30.0                         Ashworth Labs
# 449         0640_02_2.0250      12.0                         Ashworth Labs
# 450         0640_03_3.0350      12.0                         Ashworth Labs
# 451          0621_01_1.301      24.0                                  Crew
# 452           0608_00_G.27     164.0            Daniel Rutherford Building
# 453            0608_-1_B.6      40.0            Daniel Rutherford Building
# 454            0608_-1_B.7      72.0            Daniel Rutherford Building
# 455           0601_00_G.14     200.0                Eng Sanderson Building
# 456           0601_00_G.20      30.0                Eng Sanderson Building
# 457           0601_00_G.21      21.0                Eng Sanderson Building
# 458           0601_00_G.41      75.0                Eng Sanderson Building
# 459           0601_00_G.45      24.0                Eng Sanderson Building
# 460       0601_00M_G.11(M)      30.0                Eng Sanderson Building
# 461       0601_00M_G.15(M)      20.0                Eng Sanderson Building
# 462          0615_00_G.164      48.0                       Fleeming Jenkin
# 463          0615_00_G.165      12.0                       Fleeming Jenkin
# 464          0615_00_G.168      20.0                       Fleeming Jenkin
# 465         0615_01_1.196B      65.0                       Fleeming Jenkin
# 466          0615_01_1.197      40.0                       Fleeming Jenkin
# 467          0615_01_1.198      40.0                       Fleeming Jenkin
# 468            0615_01_1.2      40.0                       Fleeming Jenkin
# 469          0633_01_1.201     135.0  Geology/Geophysics (Grant Institute)
# 470         0633_03_3.304B      40.0  Geology/Geophysics (Grant Institute)
# 471           0602_00_G.10      54.0                 Hudson Beare Building
# 472            0602_00_G.2     195.0                 Hudson Beare Building
# 542          0620_00_G.128      36.0                 Peter Wilson Building
# 543          0620_00_G.155      48.0                 Peter Wilson Building
# 544           0612_01_1.02     372.0                        Swann Building
# 545           0612_07_7.15      50.0                        Swann Building
# 546           0612_07_7.20      58.0                        Swann Building
# 547           0668_00_G.02       5.0                       William Rankine
# 548           0668_01_1.18      12.0                       William Rankine
# 549        0616_04_04.12-E      72.0                                Alrick
# 642  0640_00_G.0085_G.0088      64.0                         Ashworth Labs
# 676          0621_01_1.302       NaN                                  Crew
# 677          0621_01_1.304       NaN                                  Crew
# 678           0648_00_G.02       NaN                   Roger Land Building
# 679           0648_00_G.13       NaN                   Roger Land Building
# 680           0648_01_1.55       NaN                   Roger Land Building
# 681           0670_01_1.07       NaN                 Waddington Building 1
#
#     Specialist room type
# 439     General Teaching
# 440  Computer Laboratory
# 441     General Teaching
# 442     General Teaching
# 443           Laboratory
# 444     General Teaching
# 445     General Teaching
# 446     General Teaching
# 447         Meeting Room
# 448         Meeting Room
# 449         Meeting Room
# 450         Meeting Room
# 451  Computer Laboratory
# 452     General Teaching
# 453           Laboratory
# 454           Laboratory
# 455     General Teaching
# 456           Laboratory
# 457           Laboratory
# 458     General Teaching
# 459     General Teaching
# 460           Laboratory
# 461           Laboratory
# 462  Computer Laboratory
# 463           Laboratory
# 464           Laboratory
# 465  Computer Laboratory
# 466           Laboratory
# 467           Laboratory
# 468           Laboratory
# 469     General Teaching
# 470     General Teaching
# 471     General Teaching
# 472     General Teaching
# 542           Laboratory
# 543  Computer Laboratory
# 544     General Teaching
# 545     General Teaching
# 546     General Teaching
# 547           Laboratory
# 548           Laboratory
# 549  Computer Laboratory
# 642           Laboratory
# 676         Meeting Room
# 677         Meeting Room
# 678         Meeting Room
# 679         Meeting Room
# 680         Meeting Room
# 681         Meeting Room
# rows: 49

# %%
# Rooms in Kings Buildings with missing capacity
nan_rooms = rooms_toy[rooms_toy["Capacity"].isna()]["Id"]

# Numeric conversions
emr_tmp = EMR.copy()
emr_tmp["EventSize_num"] = pd.to_numeric(emr_tmp["Event Size"], errors="coerce")
emr_tmp["Repeat_Count_num"] = pd.to_numeric(emr_tmp["Repeat_Count"], errors="coerce")

# Keep only non-repeated events
emr_tmp["Repeat_Count_num"] = emr_tmp["Repeat_Count_num"].fillna(1)
emr_nonrep = emr_tmp[emr_tmp["Repeat_Count_num"] <= 1]

# Largest event size per room, restricted to the NaN-capacity rooms
largest_by_room = (
    emr_nonrep[emr_nonrep["Room"].isin(nan_rooms)]
    .groupby("Room", dropna=True)["EventSize_num"]
    .max()
    .rename("largest_event_size_non_repeated")
)

result = (
    rooms_toy[rooms_toy["Capacity"].isna()][["Id", "Building.1", "Specialist room type"]]
    .merge(largest_by_room, left_on="Id", right_index=True, how="left")
    .sort_values("Id")
)
print(result)

rooms_toy = rooms_toy.copy()
rooms_toy["Capacity"] = pd.to_numeric(rooms_toy["Capacity"], errors="coerce")
rooms_toy.loc[rooms_toy["Capacity"].isna(), "Capacity"] = (
    rooms_toy.loc[rooms_toy["Capacity"].isna(), "Id"]
    .map(largest_by_room)
    .mul(1.0)
    .apply(lambda x: pd.NA if pd.isna(x) else int(pd.Series([x]).round(0).iloc[0]))
)

print(rooms_toy[rooms_toy["Id"].isin(nan_rooms)])
# Out:
#                 Id             Building.1 Specialist room type  \
# 676  0621_01_1.302                   Crew         Meeting Room
# 677  0621_01_1.304                   Crew         Meeting Room
# 678   0648_00_G.02    Roger Land Building         Meeting Room
# 679   0648_00_G.13    Roger Land Building         Meeting Room
# 680   0648_01_1.55    Roger Land Building         Meeting Room
# 681   0670_01_1.07  Waddington Building 1         Meeting Room
#
#      largest_event_size_non_repeated
# 676                             40.0
# 677                              6.0
# 678                             40.0
# 679                             10.0
# 680                             12.0
# 681                             12.0
#                 Id  Capacity             Building.1 Specialist room type
# 676  0621_01_1.302      40.0                   Crew         Meeting Room
# 677  0621_01_1.304       6.0                   Crew         Meeting Room
# 678   0648_00_G.02      40.0    Roger Land Building         Meeting Room
# 679   0648_00_G.13      10.0    Roger Land Building         Meeting Room
# 680   0648_01_1.55      12.0    Roger Land Building         Meeting Room
# 681   0670_01_1.07      12.0  Waddington Building 1         Meeting Room

# %%
print(rooms_toy["Specialist room type"].value_counts())
# Out:
# Specialist room type
# General Teaching       17
# Laboratory             16
# Meeting Room           10
# Computer Laboratory     6
# Name: count, dtype: int64

# %%
def keep_chosen_weeks(weeks_value):
    if pd.isna(weeks_value):
        return None

    weeks = []
    for part in str(weeks_value).split(","):
        part = part.strip()
        if "-" in part:
            start, end = map(int, part.split("-"))
            weeks.extend(range(start, end + 1))
        else:
            weeks.append(int(part))

    kept = sorted(set(w for w in weeks if 26 <= w <= 36))

    if not kept:
        return None

    return ",".join(map(str, kept))


EMR_toy = EMR[EMR["Module Department"].isin(["School of Engineering",
                                             "School of Biological Sciences", 
                                             "School of Geosciences"])].copy()

EMR_toy = EMR_toy[EMR_toy["Campus"] != "BioQuarter"].copy()

EMR_toy["Weeks"] = EMR_toy["Weeks"].apply(keep_chosen_weeks)
EMR_toy = EMR_toy[EMR_toy["Weeks"].notna()]

EMR_toy = EMR_toy[[
    "Module Department",
    "Building",
    "Event ID",
    "Module Code",
    "Duration (minutes)",
    "Event Size",
    "WholeClass",
    "Weeks",
    "Room type 2",
    "Online Delivery"
]]

EMR_toy["Room type 2"] = EMR_toy["Room type 2"].replace(
    "Centrally Allocated Space",
    "General Teaching"
)

EMR_toy["Room type 2"] = EMR_toy["Room type 2"].replace(
    "Foyer",
    "General Teaching"
)

EMR_toy["Room type 2"] = EMR_toy["Room type 2"].replace(
    "Teaching Studio",
    "General Teaching"
)

EMR_toy["Duration (minutes)"] = EMR_toy["Duration (minutes)"].clip(upper=480)

print(EMR_toy.head())
print("rows:", len(EMR_toy))
print(EMR_toy.isna().sum())
# Out:
#          Module Department Building      Event ID  \
# 89   School of Engineering   Alrick  E:O4T7BT9JA9
# 133  School of Engineering   Alrick  E:WYM6UXZOWJ
# 171  School of Engineering   Alrick  E:LMKN6Q1959
# 215  School of Engineering   Alrick  E:ETEHJR9GYQ
# 237  School of Engineering   Alrick  E:4XICMK913K
#
#                                            Module Code  Duration (minutes)  \
# 89                           PGEE11215_SS1_SEM2_2024/5                  50
# 133  ELEE10007_SV1_SEM2_2024/5, PGEE10008_SS1_SEM2_...                  50
# 171                          SCEE08015_SV1_SEM2_2024/5                  50
# 215  ELEE11111_SV1_SEM2_2024/5, PGEE11237_SV1_SEM2_...                  50
# 237  ELEE11104_SS1_SEM2_2024/5, PGEE11194_SS1_SEM2_...                  50
#
#      Event Size  WholeClass                          Weeks       Room type 2  \
# 89         22.0        True  26,27,28,29,30,32,33,34,35,36  General Teaching
# 133        44.0        True        28,29,30,32,33,34,35,36  General Teaching
# 171        50.0       False                       27,29,34  General Teaching
# 215         9.0        True     27,28,29,30,32,33,34,35,36  General Teaching
# 237        21.0       False  26,27,28,29,30,32,33,34,35,36  General Teaching
#
#     Online Delivery
# 89              NaN
# 133             NaN
# 171             NaN
# 215             NaN
# 237             NaN
# rows: 1395
# Module Department        0
# Building                 0
# Event ID                 0
# Module Code              0
# Duration (minutes)       0
# Event Size               0
# WholeClass               0
# Weeks                    0
# Room type 2              0
# Online Delivery       1395
# dtype: int64

# %%
print(EMR_toy["Room type 2"].value_counts())
# Out:
# Room type 2
# General Teaching       819
# Laboratory             402
# Computer Laboratory    142
# Meeting Room            32
# Name: count, dtype: int64

# %% [markdown]
# changed teaching studio to general teaching as they are basically the same thing

# %%
event_programme_df = SPME[["Event ID", "Programme Code-Year"]]

event_programmes = (
    event_programme_df
    .drop_duplicates()
    .groupby("Event ID")["Programme Code-Year"]
    .agg(list)
    .to_dict()
)

event_programme_toy = (
    event_programme_df
    .drop_duplicates()
    .groupby("Event ID", as_index=False)["Programme Code-Year"]
    .agg(list)
)
display(event_programme_toy.head())
print(event_programme_toy.shape)
print(event_programme_toy.isna().sum())
# Out:
#              Event ID                                Programme Code-Year
# 0        E:114K59WCRK  [UTELEEB_YR4_2024/5, UTEMENM_YR5_2024/5, UTELE...
# 1        E:117T8ZQ92F  [UTCHENB_YR4_2024/5, UTBENCHEET1F_YR4_2024/5, ...
# 2        E:117Z6VV1GW                          [PTMARTCOAP1F_YR1_2024/5]
# 3        E:11FIIGMRZ7  [UTARCSA_YR2_2024/5, UTARCHA_YR2_2024/5, UTMAH...
# 4  E:11FIIGMRZ7-00001  [UTARCSA_YR2_2024/5, UTARCHA_YR2_2024/5, UTMAH...
# (29105, 2)
# Event ID               0
# Programme Code-Year    0
# dtype: int64

# %%
df_events = EMR_toy.merge(
    event_programme_toy,
    on="Event ID",
    how="left"
)
print(df_events.head())
print("rows:", len(df_events))
df_events.isna().sum()
# Out:
#        Module Department Building      Event ID  \
# 0  School of Engineering   Alrick  E:O4T7BT9JA9
# 1  School of Engineering   Alrick  E:WYM6UXZOWJ
# 2  School of Engineering   Alrick  E:LMKN6Q1959
# 3  School of Engineering   Alrick  E:ETEHJR9GYQ
# 4  School of Engineering   Alrick  E:4XICMK913K
#
#                                          Module Code  Duration (minutes)  \
# 0                          PGEE11215_SS1_SEM2_2024/5                  50
# 1  ELEE10007_SV1_SEM2_2024/5, PGEE10008_SS1_SEM2_...                  50
# 2                          SCEE08015_SV1_SEM2_2024/5                  50
# 3  ELEE11111_SV1_SEM2_2024/5, PGEE11237_SV1_SEM2_...                  50
# 4  ELEE11104_SS1_SEM2_2024/5, PGEE11194_SS1_SEM2_...                  50
#
#    Event Size  WholeClass                          Weeks       Room type 2  \
# 0        22.0        True  26,27,28,29,30,32,33,34,35,36  General Teaching
# 1        44.0        True        28,29,30,32,33,34,35,36  General Teaching
# 2        50.0       False                       27,29,34  General Teaching
# 3         9.0        True     27,28,29,30,32,33,34,35,36  General Teaching
# 4        21.0       False  26,27,28,29,30,32,33,34,35,36  General Teaching
#
#   Online Delivery                                Programme Code-Year
# 0             NaN                          [PTMSCDDMAN1F_YR1_2024/5]
# 1             NaN  [UTELEEB_YR4_2024/5, UTELEEM_YR4_2024/5, UTELE...
# 2             NaN  [UTELECS_YR2_2024/5, UTCVENB_YR2_2024/5, UTCHE...
# 3             NaN  [UTELEEM_YR5_2024/5, UTELEEB_YR4_2024/5, UTELE...
# 4             NaN  [PTMSCELPOS1F_YR1_2024/5, UTEMENM_YR5_2024/5, ...
# rows: 1395
# Module Department         0
# Building                  0
# Event ID                  0
# Module Code               0
# Duration (minutes)        0
# Event Size                0
# WholeClass                0
# Weeks                     0
# Room type 2               0
# Online Delivery        1395
# Programme Code-Year      89
# dtype: int64

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
weeks = range(26, 37)    # weeks 26 to 36 inclusive

# Mon-Thu: 09:00-17:00 = 16 half-hour slots
# Friday: 09:00-12:00 = 6 half-hour slots
slots = range(1, 17)   # global slot index
slots_by_day = {
    "Monday": range(1, 17),
    "Tuesday": range(1, 17),
    "Wednesday": range(1, 17),
    "Thursday": range(1, 17),
    "Friday": range(1, 9),
}

timeslots = pd.DataFrame(
    [(w, d, p) for w in weeks for d in days for p in slots_by_day[d]],
    columns=["Week", "Day", "Period"]
)

print(timeslots.head())
print("Total timeslots:", len(timeslots))
# Out:
#    Week     Day  Period
# 0    26  Monday       1
# 1    26  Monday       2
# 2    26  Monday       3
# 3    26  Monday       4
# 4    26  Monday       5
# Total timeslots: 792

# %% [markdown]
# ### Setup

# %%
slot_minutes = 30 # duration of each slot

# map: Event -> duration / room type / weeks of occurence
event_to_duration = df_events.set_index("Event ID")["Duration (minutes)"].to_dict()
event_to_roomtype = df_events.set_index("Event ID")["Room type 2"].to_dict()
event_to_weeks = (
    df_events.groupby("Event ID")["Weeks"]
    .apply(lambda s: sorted(set(int(w.strip()) for v in s.dropna() for w in str(v).split(","))))
    .to_dict()
)

# %%
tmp = df_events[["Event ID", "Programme Code-Year", "WholeClass"]].copy()

# change list of programmes to one row per (event, programme)
tmp["Programme Code-Year"] = tmp["Programme Code-Year"].apply(
    lambda x: x if isinstance(x, list) else [x]
)
tmp = tmp.explode("Programme Code-Year").dropna(subset=["Programme Code-Year"])

# normalize WholeClass to binary
tmp["WholeClass_bin"] = (
    tmp["WholeClass"]
    .astype(str).str.strip().str.upper()
    .map({"TRUE": 1, "FALSE": 0, "1": 1, "0": 0})
    .fillna(0)
    .astype(int)
)

whole_ep = tmp.groupby(["Event ID", "Programme Code-Year"])["WholeClass_bin"].max()

EP = list(whole_ep.index)
WholeEP = whole_ep.to_dict()
Pset = sorted(tmp["Programme Code-Year"].unique())

print("Unique events:", df_events["Event ID"].nunique())
print("Unique (event,programme) pairs:", len(EP))
# Out:
# Unique events: 1395
# Unique (event,programme) pairs: 7251

# %%
## feasible start times for events

# Duration of events in slots
L = {e: int(math.ceil(event_to_duration[e] / slot_minutes)) for e in event_to_duration.keys()}

E = sorted(event_to_duration.keys())

# Room availability by type
Avail = rooms_toy.groupby("Specialist room type")["Id"].count().to_dict()
ROOMTYPES = sorted(set(event_to_roomtype.values()))

last_slot_by_day = {d: max(slots_by_day[d]) for d in days}

# Feasible start slots per event, by day
feasible_starts = {
    e: {
        d: [s for s in slots_by_day[d] if s <= last_slot_by_day[d] - L[e] + 1]
        for d in days
    }
    for e in E
}

# %%
anchor_events = {"E:C1997OP126", "E:K9QDWM52A1"}
buffer_slots = 2   # 1 hour on a 30-minute grid

# Programmes attached to the anchor events
anchor_programmes = set()
for e in anchor_events:
    anchor_programmes.update(event_programmes.get(e, []))

# Events that share at least one programme with the anchors
restricted_events = {
    e for e in E
    if e not in anchor_events and set(event_programmes.get(e, [])) & anchor_programmes
}

#print("Restricted events:", len(restricted_events))

# %%
# Read fixed BQ schedule for the anchor events
bq_fixed = pd.read_csv("BQ_2_30_ShortFri.csv")
bq_fixed = bq_fixed[bq_fixed["Event ID"].isin(anchor_events)].copy()

parts = bq_fixed["Time Assignment"].str.extract(r"Week (\d+), ([^,]+), (\d{2}):(\d{2})")
bq_fixed["Week"] = parts[0].astype(int)
bq_fixed["Day"] = parts[1]
bq_fixed["Hour"] = parts[2].astype(int)
bq_fixed["Minute"] = parts[3].astype(int)

# Slot 1 = 09:00 on a 30-minute grid
bq_fixed["StartSlot"] = ((bq_fixed["Hour"] - 9) * 2 + (bq_fixed["Minute"] // 30) + 1).astype(int)

# Duration lookup for the anchor events
all_event_duration = (
    EMR[["Event ID", "Duration (minutes)"]]
    .dropna(subset=["Event ID", "Duration (minutes)"])
    .drop_duplicates(subset=["Event ID"])
    .set_index("Event ID")["Duration (minutes)"]
    .to_dict()
)

bq_fixed["DurSlots"] = bq_fixed["Event ID"].map(
    lambda e: int(math.ceil(all_event_duration[e] / slot_minutes))
)

display(bq_fixed[["Event ID", "Week", "Day", "StartSlot", "DurSlots"]])
# Out:
#          Event ID  Week       Day  StartSlot  DurSlots
# 32   E:K9QDWM52A1    26  Thursday          5         7
# 76   E:K9QDWM52A1    27  Thursday          5         7
# 118  E:K9QDWM52A1    28  Thursday          5         7
# 169  E:K9QDWM52A1    29  Thursday          5         7
# 220  E:K9QDWM52A1    30  Thursday          5         7
# 289  E:K9QDWM52A1    32  Thursday          5         7
# 342  E:K9QDWM52A1    33  Thursday          5         7
# 398  E:K9QDWM52A1    34  Thursday          5         7
# 464  E:K9QDWM52A1    35  Thursday          5         7
# 519  E:K9QDWM52A1    36  Thursday          5         7

# %%
tmp_weeks = df_events[["Event ID", "Weeks"]].copy()

tmp_weeks["Weeks"] = tmp_weeks["Weeks"].astype(str).str.split(",")
tmp_weeks = tmp_weeks.explode("Weeks")
tmp_weeks["Weeks"] = tmp_weeks["Weeks"].str.strip()

events_by_week = (
    tmp_weeks.groupby("Weeks")["Event ID"]
    .nunique()
    .reset_index(name="Number of Events")
    .sort_values("Weeks", key=lambda s: s.astype(int))
)

#display(events_by_week)
print(events_by_week)
# Out:
#    Weeks  Number of Events
# 0     26               463
# 1     27               583
# 2     28               627
# 3     29               639
# 4     30               627
# 5     31                 8
# 6     32               607
# 7     33               564
# 8     34               569
# 9     35               561
# 10    36               539

# %% [markdown]
# ### Model

# %%
m1 = pyo.ConcreteModel()

m1.E = pyo.Set(initialize=E) # all events
m1.W = pyo.Set(initialize=weeks) # all weeks (1..52)
m1.D = pyo.Set(initialize=days) # all days
m1.S = pyo.Set(initialize=slots) # all slots 


m1.L = pyo.Param(m1.E, initialize=L, within=pyo.PositiveIntegers) # duration of events (given in slots)
m1.RoomType = pyo.Param(m1.E, initialize=event_to_roomtype, within=pyo.Any) # room type requirement per event

m1.P = pyo.Set(initialize=Pset) # all programmes (from Programme Code-Year), needed for WholeClass constraints
m1.EP = pyo.Set(dimen=2, initialize=EP) # all (event,programme) pairs
m1.WholeEP = pyo.Param(m1.EP, initialize=WholeEP, within=pyo.Binary, default=0) # 1 if that (event,programme) pair is WholeClass, else 0

# %%
# Build based on feasible start slots and feasible weeks
X_index = [
    (e, w, d, s)
    for e in E
    for w in event_to_weeks[e]
    for d in days
    for s in feasible_starts[e][d]
]

m1.X = pyo.Set(dimen=4, initialize=X_index)
m1.x = pyo.Var(m1.X, domain=pyo.Binary) # 1 if event e starts in week w on day d at slot s

# %% [markdown]
# ### Constraints

# %%
# Same day and Start slot across all of an event's weeks. 

# = 1 if event e starts on day d and timeslot s
m1.Y = pyo.Set(dimen=3,initialize=[(e,d,s) for e in E for d in days for s in feasible_starts[e][d]])
m1.y = pyo.Var(m1.Y, domain=pyo.Binary)

# each event must choose exactly one (day,startslot) pair
def one_pattern(m, e):
    return sum(m.y[e,d,s] for d in m.D for s in feasible_starts[e][d]) == 1
m1.one_pattern = pyo.Constraint(m1.E, rule=one_pattern)

# each event must have same day and startslot in each week
def link_pattern(m, e, w, d, s):
    if (e,d,s) not in m.Y:
        return pyo.Constraint.Skip
    return m.x[e,w,d,s] == m.y[e,d,s]
m1.link_pattern = pyo.Constraint(m1.X, rule=link_pattern)

# %%
# Events belonging to same programme as other events previously scheduled in BioQuarter assignment, 
# cannot start within an hour either side of those events scheduled times

blocked_y = set()

for _, row in bq_fixed.iterrows():
    w = int(row["Week"])
    d = row["Day"]
    a_start = int(row["StartSlot"])
    a_len = int(row["DurSlots"])
    a_end = a_start + a_len - 1

    # Buffered occupied interval for the fixed BQ event
    buf_start = a_start - buffer_slots
    buf_end = a_end + buffer_slots

    for e in restricted_events:
        # Because e must use the same (day, start) in every week,
        # only block patterns for events that are active in this protected week.
        if w not in event_to_weeks[e]:
            continue

        e_len = L[e]

        for s in feasible_starts[e][d]:
            e_end = s + e_len - 1

            # Block pattern if its occupied interval intersects the buffered anchor window
            if max(s, buf_start) <= min(e_end, buf_end):
                blocked_y.add((e, d, s))

m1.BlockedY = pyo.Set(dimen=3, initialize=sorted(blocked_y))

def bq_buffer_pattern_rule(m, e, d, s):
    return m.y[e, d, s] == 0

m1.bq_buffer_pattern = pyo.Constraint(m1.BlockedY, rule=bq_buffer_pattern_rule)

# %%
# 2) Room capacity constraints directly from start variables x
### allows general teaching to take place in any room
### allows teaching studio to take place in general teaching

NO_ROOM = "No room required"
Avail = rooms_toy.groupby("Specialist room type")["Id"].count().to_dict()
ALL_ROOM_TYPES = tuple(sorted(Avail))

def compatible_room_types(required_type):
    if pd.isna(required_type) or required_type == NO_ROOM:
        return tuple()
    if required_type == "General Teaching":
        return ALL_ROOM_TYPES
    if required_type == "Teaching Studio":
        return tuple(rt for rt in ["General Teaching", "Teaching Studio"] if rt in Avail)
    return (required_type,) if required_type in Avail else tuple()

event_room_options = {e: compatible_room_types(event_to_roomtype[e]) for e in E}

# Use pool constraints: events whose allowed rooms are contained in a pool
# cannot exceed the total capacity of that pool.
room_pools = sorted({opts for opts in event_room_options.values() if opts}, key=lambda x: (len(x), x))
pool_labels = {pool: " | ".join(pool) for pool in room_pools}
pool_caps = {pool_labels[pool]: sum(Avail[rt] for rt in pool) for pool in room_pools}

m1.R = pyo.Set(initialize=list(pool_caps.keys()))

starts_covering_wdst = defaultdict(list)

for e in E:
    opts = set(event_room_options[e])
    if not opts:
        continue

    Le = L[e]

    for w in event_to_weeks[e]:
        for d in days:
            for s in feasible_starts[e][d]:
                end_s = s + Le - 1
                for t in range(s, min(end_s, max(slots_by_day[d])) + 1):
                    for pool in room_pools:
                        if opts.issubset(pool):
                            key = (w, d, t, pool_labels[pool])
                            starts_covering_wdst[key].append((e, w, d, s))

RoomCap_index = list(starts_covering_wdst.keys())
m1.RoomCapIndex = pyo.Set(dimen=4, initialize=RoomCap_index)

def room_cap_rule(m, w, d, t, r):
    idxs = starts_covering_wdst[(w, d, t, r)]
    return sum(m.x[e, w, d, s] for (e, w, d, s) in idxs) <= pool_caps[r]

m1.room_cap = pyo.Constraint(m1.RoomCapIndex, rule=room_cap_rule)

# %% [markdown]
# ### Solve

# %%
m1.obj = pyo.Objective(expr=0, sense=pyo.minimize)

# %%
solver = pyo.SolverFactory("gurobi")

# Optional but useful
#solver.options["MIPGap"] = 0.0
#solver.options["TimeLimit"] = 600  

res = solver.solve(m1, tee=True)
print("Termination:", res.solver.termination_condition)
print("Status:", res.solver.status)
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmpprzjt7vw.pyomo.lp
# Reading time = 3.35 seconds
# x1: 344295 rows, 419558 columns, 2259643 nonzeros
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 344295 rows, 419558 columns and 2259643 nonzeros (Min)
# Model fingerprint: 0x7bf18a16
# Model has 0 linear objective coefficients
# Variable types: 1 continuous, 419557 integer (419557 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Presolve removed 340125 rows and 340081 columns
# Presolve time: 1.20s
# Presolved: 4170 rows, 79477 columns, 1575353 nonzeros
# Variable types: 0 continuous, 79477 integer (79477 binary)
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 2.11 seconds (0.90 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Termination: optimal
# Status: ok

# %%
x_start = {idx: int(round(pyo.value(m1.x[idx]))) for idx in m1.X}
y_start = {idx: int(round(pyo.value(m1.y[idx]))) for idx in m1.Y}

# %%
# Whole-class programmes by event
whole_progs = {}
for (e, p), v in WholeEP.items():
    if v == 1:
        whole_progs.setdefault(e, set()).add(p)

# Build pair-specific conflict terms directly in the objective.
# This avoids introducing millions of overlap-link constraints.
pair_conflict_terms = {}
pair_weight = {}

for e1, e2 in combinations(sorted(E), 2):
    shared_progs = whole_progs.get(e1, set()) & whole_progs.get(e2, set())
    if not shared_progs:
        continue

    common_weeks = set(event_to_weeks[e1]) & set(event_to_weeks[e2])
    if not common_weeks:
        continue

    # Weight choice:
    # 1 -> penalize each clashing event pair once
    # len(shared_progs) -> penalize by number of shared whole-class programmes
    # len(shared_progs) * len(common_weeks) -> penalize by programmes and weeks affected
    pair_weight[(e1, e2)] = len(shared_progs) * len(common_weeks)

    terms = []
    L1, L2 = L[e1], L[e2]
    for d in days:
        for s1 in feasible_starts[e1][d]:
            end1 = s1 + L1 - 1
            for s2 in feasible_starts[e2][d]:
                end2 = s2 + L2 - 1
                if max(s1, s2) <= min(end1, end2):
                    terms.append((d, s1, s2))

    if terms:
        pair_conflict_terms[(e1, e2)] = terms

overlap_penalty = sum(
    pair_weight[e1, e2] * sum(
        m1.y[e1, d, s1] * m1.y[e2, d, s2]
        for (d, s1, s2) in pair_conflict_terms[e1, e2]
    )
    for (e1, e2) in pair_conflict_terms
)

# %%
# Replace the feasibility objective with the soft-constraint objective
m1.del_component(m1.obj)

w_o = 1
total_penalty = w_o * overlap_penalty
m1.obj = pyo.Objective(expr=total_penalty, sense=pyo.minimize)

# Load the stage-1 solution back as a MIP start
for idx, val in x_start.items():
    m1.x[idx].value = val

for idx, val in y_start.items():
    m1.y[idx].value = val

# %%
solver = pyo.SolverFactory("gurobi")
solver.options["NonConvex"] = 2
solver.options["MIPFocus"] = 1
#solver.options["Heuristics"] = 0.4
#solver.options["NoRelHeurTime"] = 1000
solver.options["TimeLimit"] = 600

res2 = solver.solve(m1, tee=True, warmstart=True)
print("Stage 2 termination:", res2.solver.termination_condition)
print("Stage 2 status:", res2.solver.status)
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmpqdi2h7qf.pyomo.lp
# Reading time = 6.35 seconds
# x1: 344295 rows, 419557 columns, 2259643 nonzeros
# Read MIP start from file C:\Users\asher\AppData\Local\Temp\tmp9w0wfkvx.gurobi.mst
# Set parameter NonConvex to value 2
# Set parameter MIPFocus to value 1
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  600
# MIPFocus  1
# NonConvex  2
#
# Optimize a model with 344295 rows, 419557 columns and 2259643 nonzeros (Min)
# Model fingerprint: 0x7eee82a8
# Model has 0 linear objective coefficients
# Model has 2567052 quadratic objective terms
# Variable types: 0 continuous, 419557 integer (419557 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# Loaded user MIP start with objective 15685
#
# Presolve removed 340125 rows and 340080 columns (presolve time = 120s)...
# Presolve removed 340125 rows and 340080 columns
# Presolve time: 119.87s
# Presolved: 31836 rows, 107143 columns, 4190243 nonzeros
# Found heuristic solution: objective 15681.000000
# Variable types: 0 continuous, 107143 integer (79488 binary)
# Performing another presolve...
# Presolve removed 474 rows and 0 columns (presolve time = 5s)...
# Presolve removed 474 rows and 0 columns (presolve time = 10s)...
# Presolve removed 764 rows and 0 columns (presolve time = 15s)...
# Presolve removed 764 rows and 5130 columns (presolve time = 20s)...
# Presolve removed 765 rows and 5130 columns (presolve time = 25s)...
# Presolve removed 765 rows and 5130 columns (presolve time = 30s)...
# Presolve removed 765 rows and 5130 columns (presolve time = 35s)...
# Presolve removed 765 rows and 5130 columns
# Presolve time: 36.00s
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.95s
#
# Barrier performed 0 iterations in 174.35 seconds (52.56 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.60s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2659    0.0000000e+00   0.000000e+00   0.000000e+00    174s
#
# Root relaxation: objective 0.000000e+00, 2659 iterations, 11.00 seconds (3.36 work units)
# Total elapsed time = 174.49s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0  123 15662.0000    0.00000   100%     -  183s
# H    0     0                    1798.0000000    0.00000   100%     -  185s
# H    0     0                    1582.0000000    0.00000   100%     -  187s
# H    0     0                    1474.0000000    0.00000   100%     -  189s
# H    0     0                    1285.0000000    0.00000   100%     -  191s
# H    0     0                    1266.0000000    0.00000   100%     -  191s
# H    0     0                    1250.0000000    0.00000   100%     -  191s
# H    0     0                    1242.0000000    0.00000   100%     -  192s
# H    0     0                    1218.0000000    0.00000   100%     -  194s
# H    0     0                    1214.0000000    0.00000   100%     -  196s
#      0     0    0.00000    0  369 1214.00000    0.00000   100%     -  210s
# H    0     0                    1193.0000000    0.00000   100%     -  213s
# H    0     0                    1185.0000000    0.00000   100%     -  218s
# H    0     0                    1168.0000000    0.00000   100%     -  218s
# H    0     0                    1145.0000000    0.00000   100%     -  218s
# H    0     0                    1143.0000000    0.00000   100%     -  219s
# H    0     0                    1086.0000000    0.00000   100%     -  219s
# H    0     0                    1076.0000000    0.00000   100%     -  220s
# H    0     0                    1075.0000000    0.00000   100%     -  220s
# H    0     0                    1073.0000000    0.00000   100%     -  221s
#      0     0    0.00000    0  357 1073.00000    0.00000   100%     -  231s
#      0     0    0.00000    0  486 1073.00000    0.00000   100%     -  242s
#      0     0    0.00000    0  486 1073.00000    0.00000   100%     -  242s
#      0     0    0.00000    0  110 1073.00000    0.00000   100%     -  253s
# H    0     0                    1038.0000000    0.00000   100%     -  256s
#      0     0    0.00000    0  122 1038.00000    0.00000   100%     -  257s
#      0     0    0.00000    0  373 1038.00000    0.00000   100%     -  262s
#      0     0    0.00000    0  373 1038.00000    0.00000   100%     -  262s
#      0     0    0.00000    0  105 1038.00000    0.00000   100%     -  274s
# H    0     0                    1023.0000000    0.00000   100%     -  279s
# H    0     0                    1021.0000000    0.00000   100%     -  280s
# H    0     0                     989.0000000    0.00000   100%     -  280s
# H    0     0                     982.0000000    0.00000   100%     -  281s
# H    0     0                     978.0000000    0.00000   100%     -  282s
# H    0     0                     977.0000000    0.00000   100%     -  283s
# H    0     0                     972.0000000    0.00000   100%     -  287s
# H    0     0                     970.0000000    0.00000   100%     -  294s
# H    0     0                     967.0000000    0.00000   100%     -  294s
# H    0     0                     962.0000000    0.00000   100%     -  294s
#      0     0    0.00000    0  121  962.00000    0.00000   100%     -  302s
#      0     0    0.00000    0  360  962.00000    0.00000   100%     -  306s
#      0     0    0.00000    0  360  962.00000    0.00000   100%     -  306s
#      0     0    0.00000    0  120  962.00000    0.00000   100%     -  321s
# H    0     0                     955.0000000    0.00000   100%     -  323s
#      0     0    0.00000    0  124  955.00000    0.00000   100%     -  325s
#      0     0    0.00000    0  293  955.00000    0.00000   100%     -  329s
#      0     0    0.00000    0   99  955.00000    0.00000   100%     -  342s
# H    0     0                     950.0000000    0.00000   100%     -  350s
# H    0     0                     927.0000000    0.00000   100%     -  352s
# H    0     0                     899.0000000    0.00000   100%     -  407s
# H    0     0                     898.0000000    0.00000   100%     -  408s
# H    0     0                     887.0000000    0.00000   100%     -  408s
# H    0     0                     864.0000000    0.00000   100%     -  416s
# H    0     0                     855.0000000    0.00000   100%     -  418s
# H    0     0                     853.0000000    0.00000   100%     -  421s
# H    0     0                     849.0000000    0.00000   100%     -  440s
# H    0     2                     799.0000000    0.00000   100%     -  460s
#      0     2    0.00000    0   99  799.00000    0.00000   100%     -  460s
# H    1     4                     776.0000000    0.00000   100%   0.0  467s
#      3     8    0.00000    2  230  776.00000    0.00000   100%   187  470s
#     11    44    0.00000    4  224  776.00000    0.00000   100%  70.8  481s
#     43    84    0.00000   12  254  776.00000    0.00000   100%  36.0  494s
# H   83    88                     775.0000000    0.00000   100%  27.8  511s
# H   84    88                     774.0000000    0.00000   100%  27.5  511s
# H   85    88                     764.0000000    0.00000   100%  27.4  511s
# H   87    92                     762.0000000    0.00000   100%  27.2  531s
# H   88    92                     754.0000000    0.00000   100%  26.9  531s
# H   89    92                     750.0000000    0.00000   100%  27.1  531s
#     91   204    0.00000   24  263  750.00000    0.00000   100%  27.1  562s
# H  203   208                     690.0000000    0.00000   100%  21.5  600s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 18
#   MIR: 49
#   StrongCG: 6
#   RLT: 43
#   Relax-and-lift: 8
#
# Explored 207 nodes (56050 simplex iterations) in 601.56 seconds (252.95 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 690 750 754 ... 849
#
# Time limit reached
# Best objective 6.900000000000e+02, best bound 0.000000000000e+00, gap 100.0000%
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
# Stage 2 termination: maxTimeLimit
# Stage 2 status: aborted

# %%
# Export event assignments to CSV
start_rows = []
for (e, w, d, s) in m1.X:
    if pyo.value(m1.x[e, w, d, s]) > 0.5:
        start_rows.append((e, w, d, s))

event_output = pd.DataFrame(start_rows, columns=["Event ID", "Week", "Day", "StartSlot"])
event_output = event_output.sort_values(["Week", "Day", "StartSlot", "Event ID"]).reset_index(drop=True)

slot_to_time = {
    s: f"{9 + (s-1)//2:02d}:{30 if (s-1)%2 else 0:02d}"
    for s in slots
}
event_output["StartTime"] = event_output["StartSlot"].map(slot_to_time)

event_info = (
    EMR_toy[["Event ID", "Event Size", "Room type 2", "Online Delivery"]]
    .drop_duplicates(subset=["Event ID"])
    .rename(columns={
        "Room type 2": "Room Type",
        "Online Delivery": "Online Status"
    })
)

event_info["Online Status"] = (
    event_info["Online Status"]
    .fillna("Not online")
    .replace({
        "Online Live": "Online Live",
        "Online Placeholder": "Online Placeholder"
    })
)

event_info["Campus"] = "Kings Buildings"

event_output = event_output.merge(event_info, on="Event ID", how="left")
event_output["Time Assignment"] = (
    "Week " + event_output["Week"].astype(str)
    + ", " + event_output["Day"].astype(str)
    + ", " + event_output["StartTime"].astype(str)
)

event_output_csv = event_output[
    ["Event ID", "Time Assignment", "Event Size", "Room Type", "Online Status", "Campus"]
]
display(event_output_csv.head(20))

event_output_csv.to_csv("KB_eng_geo_bio_30_ShortFri.csv", index=False)
print("Saved: KB_eng_geo_bio_30_ShortFri.csv")
# Out:
#               Event ID         Time Assignment  Event Size  \
# 0   E:59ONNXLAUO-00002  Week 26, Friday, 09:00        30.0
# 1         E:6EMS7AXHLF  Week 26, Friday, 09:00         8.0
# 2         E:6KPPTKQQZZ  Week 26, Friday, 09:00       160.0
# 3         E:93XH83VRJS  Week 26, Friday, 09:00        40.0
# 4         E:9BUHDGVQCJ  Week 26, Friday, 09:00         8.0
# 5         E:9KLW1Y4TT5  Week 26, Friday, 09:00        88.0
# 6   E:HXI967RRB5-00001  Week 26, Friday, 09:00        30.0
# 7         E:J3EBOXVW34  Week 26, Friday, 09:00        57.0
# 8         E:KNQ5M3JVVZ  Week 26, Friday, 09:00        12.0
# 9         E:MMNZ9JWD9G  Week 26, Friday, 09:00        40.0
# 10        E:P1NAUHMESE  Week 26, Friday, 09:00        45.0
# 11        E:QS5XLOCV7A  Week 26, Friday, 09:00       120.0
# 12        E:SK1LRZH999  Week 26, Friday, 09:00         7.0
# 13  E:5K3JWAFYT2-00002  Week 26, Friday, 10:00       135.0
# 14        E:BVB6RTKPJF  Week 26, Friday, 10:00        40.0
# 15        E:BZ7X93T51S  Week 26, Friday, 10:00        12.0
# 16        E:DL1URQ86HI  Week 26, Friday, 10:00        44.0
# 17        E:E2H3ZQEM19  Week 26, Friday, 10:00        99.0
# 18        E:HMMMU5N83V  Week 26, Friday, 10:00        25.0
# 19        E:HQ5DK4BTBV  Week 26, Friday, 10:00         8.0
#
#               Room Type Online Status           Campus
# 0      General Teaching    Not online  Kings Buildings
# 1      General Teaching    Not online  Kings Buildings
# 2      General Teaching    Not online  Kings Buildings
# 3   Computer Laboratory    Not online  Kings Buildings
# 4   Computer Laboratory    Not online  Kings Buildings
# 5      General Teaching    Not online  Kings Buildings
# 6      General Teaching    Not online  Kings Buildings
# 7      General Teaching    Not online  Kings Buildings
# 8          Meeting Room    Not online  Kings Buildings
# 9      General Teaching    Not online  Kings Buildings
# 10  Computer Laboratory    Not online  Kings Buildings
# 11     General Teaching    Not online  Kings Buildings
# 12     General Teaching    Not online  Kings Buildings
# 13     General Teaching    Not online  Kings Buildings
# 14     General Teaching    Not online  Kings Buildings
# 15  Computer Laboratory    Not online  Kings Buildings
# 16     General Teaching    Not online  Kings Buildings
# 17     General Teaching    Not online  Kings Buildings
# 18     General Teaching    Not online  Kings Buildings
# 19     General Teaching    Not online  Kings Buildings
# Saved: KB_eng_geo_bio_30_ShortFri.csv

# %% [markdown]
# ### Room Assignment

# %%
schedule_csv = "KB_eng_geo_bio_30_ShortFri.csv"
slot_minutes = 30

# %%
### Room Assignment Input

assign_df = pd.read_csv(schedule_csv)

# Keep only in-person events that need a room
assign_df = assign_df[
    (assign_df["Online Status"] == "Not online") &
    assign_df["Room Type"].notna() &
    (assign_df["Room Type"] != "No room required")
].copy()

# Parse "Week 9, Friday, 09:00"
parts = assign_df["Time Assignment"].str.extract(r"Week (\d+), ([^,]+), (\d{2}):(\d{2})")
assign_df["Week"] = parts[0].astype(int)
assign_df["Day"] = parts[1]
assign_df["Hour"] = parts[2].astype(int)
assign_df["Minute"] = parts[3].astype(int)

if slot_minutes == 30:
    assign_df["StartSlot"] = ((assign_df["Hour"] - 9) * 2 + (assign_df["Minute"] // 30) + 1).astype(int)
else:
    assign_df["StartSlot"] = ((assign_df["Hour"] - 9) + 1).astype(int)

# Bring in event durations
event_durations = (
    EMR[["Event ID", "Duration (minutes)"]]
    .dropna(subset=["Event ID", "Duration (minutes)"])
    .drop_duplicates(subset=["Event ID"])
)

assign_df = assign_df.merge(event_durations, on="Event ID", how="left")
assign_df["DurSlots"] = assign_df["Duration (minutes)"].apply(lambda x: int(math.ceil(x / slot_minutes)))

# Unique scheduled occurrence key
assign_df["OccKey"] = list(zip(
    assign_df["Event ID"],
    assign_df["Week"],
    assign_df["Day"],
    assign_df["StartSlot"]
))

display(assign_df.head())
print("Events to room-assign:", len(assign_df))
# Out:
#              Event ID         Time Assignment  Event Size  \
# 0  E:59ONNXLAUO-00002  Week 26, Friday, 09:00        30.0
# 1        E:6EMS7AXHLF  Week 26, Friday, 09:00         8.0
# 2        E:6KPPTKQQZZ  Week 26, Friday, 09:00       160.0
# 3        E:93XH83VRJS  Week 26, Friday, 09:00        40.0
# 4        E:9BUHDGVQCJ  Week 26, Friday, 09:00         8.0
#
#              Room Type Online Status           Campus  Week     Day  Hour  \
# 0     General Teaching    Not online  Kings Buildings    26  Friday     9
# 1     General Teaching    Not online  Kings Buildings    26  Friday     9
# 2     General Teaching    Not online  Kings Buildings    26  Friday     9
# 3  Computer Laboratory    Not online  Kings Buildings    26  Friday     9
# 4  Computer Laboratory    Not online  Kings Buildings    26  Friday     9
#
#    Minute  StartSlot  Duration (minutes)  DurSlots  \
# 0       0          1                  50         2
# 1       0          1                  50         2
# 2       0          1                 110         4
# 3       0          1                  50         2
# 4       0          1                 170         6
#
#                                 OccKey
# 0  (E:59ONNXLAUO-00002, 26, Friday, 1)
# 1        (E:6EMS7AXHLF, 26, Friday, 1)
# 2        (E:6KPPTKQQZZ, 26, Friday, 1)
# 3        (E:93XH83VRJS, 26, Friday, 1)
# 4        (E:9BUHDGVQCJ, 26, Friday, 1)
# Events to room-assign: 5787

# %%
### Room Candidates and Penalties

rooms_assign = rooms_toy.copy()

def compatible_room(required_type, room_type):
    if pd.isna(required_type) or pd.isna(room_type):
        return False
    if required_type == "General Teaching":
        return True
    if required_type == "Teaching Studio":
        return room_type in {"Teaching Studio", "General Teaching"}
    return room_type == required_type

occurrences = assign_df["OccKey"].tolist()
rooms_list = rooms_assign["Id"].tolist()

occ_req_type = assign_df.set_index("OccKey")["Room Type"].to_dict()
occ_size = assign_df.set_index("OccKey")["Event Size"].to_dict()
occ_week = assign_df.set_index("OccKey")["Week"].to_dict()
occ_day = assign_df.set_index("OccKey")["Day"].to_dict()
occ_start = assign_df.set_index("OccKey")["StartSlot"].to_dict()
occ_len = assign_df.set_index("OccKey")["DurSlots"].to_dict()
occ_event = assign_df.set_index("OccKey")["Event ID"].to_dict()

room_type = rooms_assign.set_index("Id")["Specialist room type"].to_dict()
room_cap = rooms_assign.set_index("Id")["Capacity"].to_dict()

candidate_pairs = []
linear_penalty = {}
quadratic_penalty = {}

for occ in occurrences:
    req = occ_req_type[occ]
    size = float(occ_size[occ])

    for r in rooms_list:
        if compatible_room(req, room_type[r]):
            cap = room_cap[r]
            shortfall = 0 if pd.isna(cap) else max(0.0, size - float(cap))

            candidate_pairs.append((occ, r))
            linear_penalty[(occ, r)] = shortfall
            quadratic_penalty[(occ, r)] = shortfall ** 2

print("Candidate occurrence-room pairs:", len(candidate_pairs))
# Out:
# Candidate occurrence-room pairs: 229023

# %%
occupancy = defaultdict(list)

for occ in occurrences:
    w = occ_week[occ]
    d = occ_day[occ]
    s0 = occ_start[occ]
    L = occ_len[occ]

    for t in range(s0, s0 + L):
        occupancy[(w, d, t)].append(occ)

occ_index = list(occupancy.keys())
print("Occupied time indices:", len(occ_index))
# Out:
# Occupied time indices: 759

# %%
m2 = pyo.ConcreteModel()

m2.O = pyo.Set(initialize=occurrences, dimen=4)
m2.R = pyo.Set(initialize=rooms_list)
m2.A = pyo.Set(dimen=5, initialize=[(e, w, d, s, r) for ((e, w, d, s), r) in candidate_pairs])
m2.Occ = pyo.Set(dimen=3, initialize=occ_index)

m2.z = pyo.Var(m2.A, domain=pyo.Binary)

# Each occurrence gets exactly one room
def one_room_rule(m, e, w, d, s):
    return sum(m.z[e, w, d, s, r] for r in m.R if (e, w, d, s, r) in m.A) == 1
m2.one_room = pyo.Constraint(m2.O, rule=one_room_rule)

# No room can host two occurrences in the same occupied slot
def no_clash_rule(m, w, d, t, r):
    occs = occupancy[(w, d, t)]
    feasible = [(e, ww, dd, ss, r) for (e, ww, dd, ss) in occs if (e, ww, dd, ss, r) in m.A]
    if not feasible:
        return pyo.Constraint.Skip
    return sum(m.z[e, ww, dd, ss, r] for (e, ww, dd, ss, r) in feasible) <= 1
m2.no_clash = pyo.Constraint(m2.Occ, m2.R, rule=no_clash_rule)

# %%
m2.obj = pyo.Objective(
    expr=sum(quadratic_penalty[((e, w, d, s), r)] * m2.z[e, w, d, s, r] for (e, w, d, s, r) in m2.A),
    sense=pyo.minimize
)

# %%
solver = pyo.SolverFactory("gurobi")

#solver.options["NonConvex"] = 2
#solver.options["MIPFocus"] = 1
#solver.options["Heuristics"] = 0.4
#solver.options["NoRelHeurTime"] = 1000
solver.options["TimeLimit"] = 100

res_room = solver.solve(m2, tee=True)

print("Room assignment termination:", res_room.solver.termination_condition)
print("Room assignment status:", res_room.solver.status)

linear_total = sum(
    linear_penalty[((e, w, d, s), r)] * pyo.value(m2.z[e, w, d, s, r])
    for (e, w, d, s, r) in m2.A
)

quadratic_total = sum(
    quadratic_penalty[((e, w, d, s), r)] * pyo.value(m2.z[e, w, d, s, r])
    for (e, w, d, s, r) in m2.A
)

print("Linear penalty:", linear_total)
print("Quadratic penalty:", quadratic_total)
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmpqljrabx3.pyomo.lp
# Reading time = 1.44 seconds
# x1: 42978 rows, 229023 columns, 1009155 nonzeros
# Set parameter TimeLimit to value 100
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  100
#
# Optimize a model with 42978 rows, 229023 columns and 1009155 nonzeros (Min)
# Model fingerprint: 0xcf1223a1
# Model has 110190 linear objective coefficients
# Variable types: 0 continuous, 229023 integer (229023 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 2.735116e+07
# Presolve removed 20507 rows and 82818 columns (presolve time = 5s)...
# Presolve removed 42146 rows and 223271 columns
# Presolve time: 7.40s
# Presolved: 832 rows, 5752 columns, 23673 nonzeros
# Found heuristic solution: objective 829183.00000
# Variable types: 0 continuous, 5752 integer (5752 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2552300e+05   1.460000e+02   0.000000e+00      8s
#      759    3.2724900e+05   0.000000e+00   0.000000e+00      8s
#
# Root relaxation: objective 3.272490e+05, 759 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    327249.00000 327249.000  0.00%     -    7s
#
# Explored 1 nodes (759 simplex iterations) in 7.62 seconds (4.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 327249 829183 2.73512e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.272490000000e+05, best bound 3.272490000000e+05, gap 0.0000%
# Room assignment termination: optimal
# Room assignment status: ok
# Linear penalty: 7445.0
# Quadratic penalty: 327249.0

# %%
assigned_rooms = []
for (e, w, d, s, r) in m2.A:
    if pyo.value(m2.z[e, w, d, s, r]) > 0.5:
        assigned_rooms.append((e, w, d, s, r, room_cap[r], room_type[r]))

assigned_rooms_df = pd.DataFrame(
    assigned_rooms,
    columns=["Event ID", "Week", "Day", "StartSlot", "Assigned Room", "Room Capacity", "Assigned Room Type"]
)

final_room_output = assign_df.merge(
    assigned_rooms_df,
    on=["Event ID", "Week", "Day", "StartSlot"],
    how="left"
)

display(final_room_output.head(20))

final_room_output.to_csv("KB_eng_geo_bio_30_ShortFri_complete_assignments.csv", index=False)
print("Saved: KB_eng_geo_bio_30_ShortFri_complete_assignments.csv")
# Out:
#               Event ID         Time Assignment  Event Size  \
# 0   E:59ONNXLAUO-00002  Week 26, Friday, 09:00        30.0
# 1         E:6EMS7AXHLF  Week 26, Friday, 09:00         8.0
# 2         E:6KPPTKQQZZ  Week 26, Friday, 09:00       160.0
# 3         E:93XH83VRJS  Week 26, Friday, 09:00        40.0
# 4         E:9BUHDGVQCJ  Week 26, Friday, 09:00         8.0
# 5         E:9KLW1Y4TT5  Week 26, Friday, 09:00        88.0
# 6   E:HXI967RRB5-00001  Week 26, Friday, 09:00        30.0
# 7         E:J3EBOXVW34  Week 26, Friday, 09:00        57.0
# 8         E:KNQ5M3JVVZ  Week 26, Friday, 09:00        12.0
# 9         E:MMNZ9JWD9G  Week 26, Friday, 09:00        40.0
# 10        E:P1NAUHMESE  Week 26, Friday, 09:00        45.0
# 11        E:QS5XLOCV7A  Week 26, Friday, 09:00       120.0
# 12        E:SK1LRZH999  Week 26, Friday, 09:00         7.0
# 13  E:5K3JWAFYT2-00002  Week 26, Friday, 10:00       135.0
# 14        E:BVB6RTKPJF  Week 26, Friday, 10:00        40.0
# 15        E:BZ7X93T51S  Week 26, Friday, 10:00        12.0
# 16        E:DL1URQ86HI  Week 26, Friday, 10:00        44.0
# 17        E:E2H3ZQEM19  Week 26, Friday, 10:00        99.0
# 18        E:HMMMU5N83V  Week 26, Friday, 10:00        25.0
# 19        E:HQ5DK4BTBV  Week 26, Friday, 10:00         8.0
#
#               Room Type Online Status           Campus  Week     Day  Hour  \
# 0      General Teaching    Not online  Kings Buildings    26  Friday     9
# 1      General Teaching    Not online  Kings Buildings    26  Friday     9
# 2      General Teaching    Not online  Kings Buildings    26  Friday     9
# 3   Computer Laboratory    Not online  Kings Buildings    26  Friday     9
# 4   Computer Laboratory    Not online  Kings Buildings    26  Friday     9
# 5      General Teaching    Not online  Kings Buildings    26  Friday     9
# 6      General Teaching    Not online  Kings Buildings    26  Friday     9
# 7      General Teaching    Not online  Kings Buildings    26  Friday     9
# 8          Meeting Room    Not online  Kings Buildings    26  Friday     9
# 9      General Teaching    Not online  Kings Buildings    26  Friday     9
# 10  Computer Laboratory    Not online  Kings Buildings    26  Friday     9
# 11     General Teaching    Not online  Kings Buildings    26  Friday     9
# 12     General Teaching    Not online  Kings Buildings    26  Friday     9
# 13     General Teaching    Not online  Kings Buildings    26  Friday    10
# 14     General Teaching    Not online  Kings Buildings    26  Friday    10
# 15  Computer Laboratory    Not online  Kings Buildings    26  Friday    10
# 16     General Teaching    Not online  Kings Buildings    26  Friday    10
# 17     General Teaching    Not online  Kings Buildings    26  Friday    10
# 18     General Teaching    Not online  Kings Buildings    26  Friday    10
# 19     General Teaching    Not online  Kings Buildings    26  Friday    10
#
#     Minute  StartSlot  Duration (minutes)  DurSlots  \
# 0        0          1                  50         2
# 1        0          1                  50         2
# 2        0          1                 110         4
# 3        0          1                  50         2
# 4        0          1                 170         6
# 5        0          1                  60         2
# 6        0          1                 110         4
# 7        0          1                 110         4
# 8        0          1                 150         5
# 9        0          1                  50         2
# 10       0          1                  60         2
# 11       0          1                  50         2
# 12       0          1                 180         6
# 13       0          3                  50         2
# 14       0          3                 180         6
# 15       0          3                 170         6
# 16       0          3                  50         2
# 17       0          3                  50         2
# 18       0          3                 170         6
# 19       0          3                  50         2
#
#                                  OccKey          Assigned Room  Room Capacity  \
# 0   (E:59ONNXLAUO-00002, 26, Friday, 1)        0616_00_00.01-E           86.0
# 1         (E:6EMS7AXHLF, 26, Friday, 1)         0615_01_1.196B           65.0
# 2         (E:6KPPTKQQZZ, 26, Friday, 1)            0602_00_G.2          195.0
# 3         (E:93XH83VRJS, 26, Friday, 1)          0620_00_G.155           48.0
# 4         (E:9BUHDGVQCJ, 26, Friday, 1)          0621_01_1.301           24.0
# 5         (E:9KLW1Y4TT5, 26, Friday, 1)         0640_00_G.0070          313.0
# 6   (E:HXI967RRB5-00001, 26, Friday, 1)  0640_00_G.0085_G.0088           64.0
# 7         (E:J3EBOXVW34, 26, Friday, 1)        0616_02_02.02-E           72.0
# 8         (E:KNQ5M3JVVZ, 26, Friday, 1)         0640_01_1.0150           12.0
# 9         (E:MMNZ9JWD9G, 26, Friday, 1)          0621_01_1.302           40.0
# 10        (E:P1NAUHMESE, 26, Friday, 1)        0616_01_01.03-E           80.0
# 11        (E:QS5XLOCV7A, 26, Friday, 1)           0612_01_1.02          372.0
# 12        (E:SK1LRZH999, 26, Friday, 1)          0615_01_1.198           40.0
# 13  (E:5K3JWAFYT2-00002, 26, Friday, 3)           0608_00_G.27          164.0
# 14        (E:BVB6RTKPJF, 26, Friday, 3)          0615_01_1.197           40.0
# 15        (E:BZ7X93T51S, 26, Friday, 3)        0616_04_04.12-E           72.0
# 16        (E:DL1URQ86HI, 26, Friday, 3)        0616_00_00.01-E           86.0
# 17        (E:E2H3ZQEM19, 26, Friday, 3)           0601_00_G.14          200.0
# 18        (E:HMMMU5N83V, 26, Friday, 3)           0602_00_G.10           54.0
# 19        (E:HQ5DK4BTBV, 26, Friday, 3)         0640_02_2.0250           12.0
#
#      Assigned Room Type
# 0      General Teaching
# 1   Computer Laboratory
# 2      General Teaching
# 3   Computer Laboratory
# 4   Computer Laboratory
# 5      General Teaching
# 6            Laboratory
# 7      General Teaching
# 8          Meeting Room
# 9          Meeting Room
# 10  Computer Laboratory
# 11     General Teaching
# 12           Laboratory
# 13     General Teaching
# 14           Laboratory
# 15  Computer Laboratory
# 16     General Teaching
# 17     General Teaching
# 18     General Teaching
# 19         Meeting Room
# Saved: KB_eng_geo_bio_30_ShortFri_complete_assignments.csv
